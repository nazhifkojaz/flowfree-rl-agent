# %% [markdown]
# # FlowFree DQN Pipeline (Colab)

# %%
# Install system + Python dependencies
# !python3 -m pip install --upgrade pip
# !pip install -r requirements.txt
# !pip install -r requirements-dev.txt

# %%
# %%bash
# # Set pipeline toggles/overrides here
# PIPELINE_ARGS=(
#   --episodes 4000
#   --batch-size 64
#   --buffer-size 80000
#   --epsilon-start 1.0
#   --epsilon-end 0.10
#   --epsilon-linear-steps 4000
#   --loop-penalty -2.0
#   --loop-window 10
#   --undo-penalty -0.10
#   --disconnect-penalty -0.06
#   --degree-penalty -0.08
#   --penalty-warmup 600
#   --holdout-rollout-mode both
#   --holdout-gif true
#   --log-every 25
# )
# bash scripts/full_dqn_pipeline_env2.sh ${PIPELINE_ARGS[@]}

# %%
# !bash ./scripts/full_dqn_pipeline_env2.sh
# Out:
# bash: ./scripts/full_dqn_pipeline_env2.sh: No such file or directory
